# %%
#import libraries

import pandas as pd
import numpy as np
from datetime import datetime

# %%
#read in data

df1 = pd.read_csv('./data/full_car.csv',index_col=0)
df2 = pd.read_csv('./data/second_full_car.csv',index_col=0)

#preview data
print('The shape of the data is {}'.format(df1.shape))

df1.head()
# Out:
# The shape of the data is (14195, 9)
#    year    city  gradeScore sellingCondition  marketplacePrice  mileage  \
# 0  2015    Abia         4.7          foreign           4965000   149232
# 1  2005   Accra         4.4            local           1280000   145078
# 2  2008   Accra         4.6            local           1280000    91691
# 3  2004   Lagos         4.5            local           1567500   234797
# 4  2013  Lagos          4.8          foreign           6065000   145678
#
#   Transmission     make    model
# 0    Automatic    Honda   Accord
# 1    Automatic   Toyota  Corolla
# 2    Automatic   Toyota  Corolla
# 3    Automatic   Toyota  Corolla
# 4    Automatic  Hyundai    Azera

# %%
#rename and re-arrange df1 column name

df1 = df1.rename(columns = {'sellingCondition':'History','marketplacePrice':'Price','make':'Make','model':'Model',
                            'gradeScore':'Ratings','mileage':'Millage','year':'Year'})

df1 = df1[['Price','city','History','Millage','Ratings','Year','Make','Model','Transmission']]
df1.head()
# Out:
#      Price    city  History  Millage  Ratings  Year     Make    Model  \
# 0  4965000    Abia  foreign   149232      4.7  2015    Honda   Accord
# 1  1280000   Accra    local   145078      4.4  2005   Toyota  Corolla
# 2  1280000   Accra    local    91691      4.6  2008   Toyota  Corolla
# 3  1567500   Lagos    local   234797      4.5  2004   Toyota  Corolla
# 4  6065000  Lagos   foreign   145678      4.8  2013  Hyundai    Azera
#
#   Transmission
# 0    Automatic
# 1    Automatic
# 2    Automatic
# 3    Automatic
# 4    Automatic

# %%
df1.History.value_counts()
# Out:
# foreign    13381
# new          228
# local        110
# Name: History, dtype: int64

# %%
df1.isnull().sum()
# Out:
# Price               0
# city                0
# History           476
# Millage             0
# Ratings         13207
# Year                0
# Make                0
# Model               0
# Transmission        0
# dtype: int64

# %%
#preview data
print('The shape of the data is {}'.format(df2.shape))

df2.head()
# Out:
# The shape of the data is (3298, 10)
#          Price                                           Location  \
# 0    ₦ 357,500  Mainland 2 - SNB                              ...
# 1  ₦ 1,482,500  Ibadan - SNB                                  ...
# 2    ₦ 582,500  Abuja - SNB                                   ...
# 3    ₦ 222,500  Mainland 1 - SNB                              ...
# 4    ₦ 582,500  Mainland 1 - SNB                              ...
#
#          History    Millage Ratings  Year     Make   Model Transmission  \
# 0  Nigerian Used  259,107Km       E  1996   Nissan  Almera       Manual
# 1   Foreign Used  224,740Km       D  2003   Toyota  Matrix       Manual
# 2  Nigerian Used  188,400Km       D  2011  Hyundai     I10       Manual
# 3  Nigerian Used        1Km       D  2004      Kia     Rio       Manual
# 4  Nigerian Used  175,218Km       D  2009      Kia  Optima       Manual
#
#      Fuel
# 0  Petrol
# 1  Petrol
# 2  Petrol
# 3  Petrol
# 4  Petrol

# %%
df2.isnull().sum()
# Out:
# Price             0
# Location          0
# History           9
# Millage           0
# Ratings         178
# Year              0
# Make              0
# Model             0
# Transmission      0
# Fuel              0
# dtype: int64

# %%
#drop the fuel column
df2 = df2.drop(['Fuel'],axis=1)

#drop # in price, drop used in History, drop Km in Millage.

df2['Price'] = df2['Price'].str.replace('₦ ', '')   #drop # in price
df2['Millage'] = df2['Millage'].str.replace('Km', '')   #drop Km in Millage

#replace Nigerian Used with local and Foreign with foreign
df2.loc[df2.History.str.contains('Nigerian Used') == True,'History'] = 'local'  #replace all wrongly written values
df2.loc[df2.History.str.contains('Foreign Used') == True,'History'] = 'foreign'  #replace all wrongly written values

#clean Location
df2.Location = df2.Location.str.split(',',expand=True)[1]

#rename Location to city
df2 = df2.rename(columns = {'Location':'city'})

df2.head()
# Out:
#        Price    city  History  Millage Ratings  Year     Make   Model  \
# 0    357,500   Lagos    local  259,107       E  1996   Nissan  Almera
# 1  1,482,500  Ibadan  foreign  224,740       D  2003   Toyota  Matrix
# 2    582,500   Abuja    local  188,400       D  2011  Hyundai     I10
# 3    222,500   Lagos    local        1       D  2004      Kia     Rio
# 4    582,500   Lagos    local  175,218       D  2009      Kia  Optima
#
#   Transmission
# 0       Manual
# 1       Manual
# 2       Manual
# 3       Manual
# 4       Manual

# %%
#concat df1 and df2 dataframe

df = pd.concat([df1,df2],ignore_index=True)

#preview data
print('The shape of the data is {}'.format(df.shape))

df.head()
# Out:
# The shape of the data is (17493, 9)
#      Price    city  History Millage Ratings  Year     Make    Model  \
# 0  4965000    Abia  foreign  149232     4.7  2015    Honda   Accord
# 1  1280000   Accra    local  145078     4.4  2005   Toyota  Corolla
# 2  1280000   Accra    local   91691     4.6  2008   Toyota  Corolla
# 3  1567500   Lagos    local  234797     4.5  2004   Toyota  Corolla
# 4  6065000  Lagos   foreign  145678     4.8  2013  Hyundai    Azera
#
#   Transmission
# 0    Automatic
# 1    Automatic
# 2    Automatic
# 3    Automatic
# 4    Automatic

# %%
#replace A=5,B=4,C=3,D=2,E=1
mymap = {'A':1,'B':2,'C':3,'D':4,'E':5}
df.Ratings = df.Ratings.map(lambda s: mymap.get(s) if s in mymap else s)

df.head()
# Out:
#      Price    city  History Millage  Ratings  Year     Make    Model  \
# 0  4965000    Abia  foreign  149232      4.7  2015    Honda   Accord
# 1  1280000   Accra    local  145078      4.4  2005   Toyota  Corolla
# 2  1280000   Accra    local   91691      4.6  2008   Toyota  Corolla
# 3  1567500   Lagos    local  234797      4.5  2004   Toyota  Corolla
# 4  6065000  Lagos   foreign  145678      4.8  2013  Hyundai    Azera
#
#   Transmission
# 0    Automatic
# 1    Automatic
# 2    Automatic
# 3    Automatic
# 4    Automatic

# %%
df.History.value_counts()
# Out:
# foreign    14412
# local       2331
# new          228
# New           37
# Name: History, dtype: int64

# %%
#drop all new and New cars
unwanted_list = ['new','New']

for item in unwanted_list:
    i = df[(df.History == item)].index
    df = df.drop(i)
    
df.head()
# Out:
#      Price    city  History Millage  Ratings  Year     Make    Model  \
# 0  4965000    Abia  foreign  149232      4.7  2015    Honda   Accord
# 1  1280000   Accra    local  145078      4.4  2005   Toyota  Corolla
# 2  1280000   Accra    local   91691      4.6  2008   Toyota  Corolla
# 3  1567500   Lagos    local  234797      4.5  2004   Toyota  Corolla
# 4  6065000  Lagos   foreign  145678      4.8  2013  Hyundai    Azera
#
#   Transmission
# 0    Automatic
# 1    Automatic
# 2    Automatic
# 3    Automatic
# 4    Automatic

# %%
df.isnull().sum()
# Out:
# Price               0
# city              402
# History           485
# Millage             0
# Ratings         13189
# Year                0
# Make                0
# Model               0
# Transmission        0
# dtype: int64

# %%
#replace missing cities with column mode
city_mode = df.city.value_counts().index[0]

df['city'].fillna(city_mode, inplace = True)

#replace missing History with column mode
history_mode = df.History.value_counts().index[0]

df['History'].fillna(history_mode, inplace = True)

# %%
#clean up the city column

#clean up the lagos cities
lagos_locations = ['LAGOS','berger','Berger','Ejigbo','Alapere','Ojo','Abule Egba','JABI','C45','other',
                     'Lekki','Lagos',' Ikorodu.','Bank Anthony','ACME Road','Ogba','Mushin','Akoka','Ogba','lagos']

for item in lagos_locations:
    df.loc[df.city.str.contains(item) == True,'city'] = 'Lagos'  #clean up the Lagos cities


#clean up  ogun cities
ogun_locations =['Arepo, Ogun state','Arepo ogun state','Ogun']

for item in ogun_locations:
    df.loc[df.city.str.contains(item) == True,'city'] = 'Ogun'  #clean up the Ogun cities


#convert city column to string
df.city = df.city.astype(str)

# %%
#round off df.Ratings column to 2dp.

df['Ratings'] = df['Ratings'].round(3)

# %%
df.isnull().sum()
# Out:
# Price               0
# city                0
# History             0
# Millage             0
# Ratings         13189
# Year                0
# Make                0
# Model               0
# Transmission        0
# dtype: int64

# %%
print('The shape of the data is {}'.format(df.shape))
# Out:
# The shape of the data is (17228, 9)

# %%
df.tail()
# Out:
#            Price   city  History  Millage  Ratings  Year           Make  \
# 17488  9,893,906  Lagos    local   28,027      4.0  2016  Mercedes-Benz
# 17489  2,974,400  Lagos  foreign  163,978      2.0  2011         Toyota
# 17490  4,202,500  Lagos  foreign  103,147      3.0  2009         Toyota
# 17491  2,140,000  Lagos  foreign  148,118      3.0  2007          Lexus
# 17492  1,890,000  Lagos  foreign   29,654      3.0  2006  Mercedes-Benz
#
#         Model Transmission
# 17488    C300    Automatic
# 17489   Camry    Automatic
# 17490   Venza    Automatic
# 17491      ES    Automatic
# 17492  Ml350     Automatic

# %%
df.isna().sum()
# Out:
# Price               0
# city                0
# History             0
# Millage             0
# Ratings         13189
# Year                0
# Make                0
# Model               0
# Transmission        0
# dtype: int64

# %%
df.dtypes
# Out:
# Price            object
# city             object
# History          object
# Millage          object
# Ratings         float64
# Year             object
# Make             object
# Model            object
# Transmission     object
# dtype: object

# %%
#clean the year column
#drop every element containing NG. 

column_year_mode = df.Year.value_counts().index[0]
             
df.loc[df.Year.str.contains('NG') == True,'Year'] = column_year_mode  #replace all wrongly written values
df.loc[df.Year.str.contains('0') == True,'Year'] = column_year_mode  #replace all zero values with column mode

# %%
#convert the Year column to numbers
df.Year = df['Year'].astype(str).astype(int)

#present_year
present_year = datetime.now().year

#create an Age column
df['Age'] = present_year - df.Year #age = year - 2020

# %%
#convert Price, Millage, Ratings, Year and age to Float(numbers)

df['Price'] = df['Price'].str.replace(",", "")  #remove commas from Price
df.Price = df.Price.str.split('\n',expand=True)[0]

df['Millage'] = df['Millage'].str.replace(",", "")  #remove commas from Millage

list_float = ['Price','Millage','Ratings','Year','Age']
for item in list_float:
    df[item] = df[item].astype(float)

# %%
#save data temporarily
df.to_csv('./data/cleaned_data.csv')

# %%
df.head()
# Out:
#    Price   city  History  Millage  Ratings    Year     Make    Model  \
# 0    NaN   Abia  foreign      NaN      4.7  2015.0    Honda   Accord
# 1    NaN  Accra    local      NaN      4.4  2005.0   Toyota  Corolla
# 2    NaN  Accra    local      NaN      4.6  2008.0   Toyota  Corolla
# 3    NaN  Lagos    local      NaN      4.5  2004.0   Toyota  Corolla
# 4    NaN  Lagos  foreign      NaN      4.8  2013.0  Hyundai    Azera
#
#   Transmission   Age
# 0    Automatic   5.0
# 1    Automatic  15.0
# 2    Automatic  12.0
# 3    Automatic  16.0
# 4    Automatic   7.0

# %%
#fill up the rating column
df.Ratings.isnull().sum()
# Out:
# 13189

# %%
#replace values with number 2
#df.Ratings.fillna(2, inplace=True)

#save data to disk
#df.to_csv('./data/cleaned_data_with2.csv')

# %%
#replace values with number 2
#df.Ratings.fillna(3, inplace=True)

#save data to disk
#df.to_csv('./data/cleaned_data_with3.csv')

# %%
df.isnull().sum()
# Out:
# Price           13967
# city                0
# History             0
# Millage         13967
# Ratings             0
# Year                0
# Make                0
# Model               0
# Transmission        0
# Age                 0
# dtype: int64

# %%
df.city.value_counts()
# Out:
# Lagos            15580
# Abuja              660
# Port Harcourt      274
# Ibadan             123
# Rivers             122
# Onitsha             66
# Osun                56
# Kaduna              55
# Owerri              51
# Ilorin              48
# Kano                42
# Enugu               30
# Asaba               28
# Benin               27
# Ogun                25
# Kwara                9
# Cross-river          8
# Abia                 5
# Anambra              4
# Edo                  3
# Imo                  3
# Oyo                  3
# Accra                3
# Delta                2
# Abia                 1
# Name: city, dtype: int64
